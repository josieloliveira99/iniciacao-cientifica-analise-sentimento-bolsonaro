# %%
import pandas as pd
import random
import utils.functions as f
from utils.stop_words_custom import my_stop_words as stop_words
pd.set_option('display.max_colwidth', -1)

# %%
data = "data/00_initial/40.xlsx"

# %%
df = f.get_data(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
# id                      100000 non-null int64
# guid                    100000 non-null object
# link                    100000 non-null object
# pubdate                 100000 non-null object
# author                  100000 non-null object
# title                   100000 non-null object
# description             100000 non-null object
# source                  100000 non-null object
# user_id                 100000 non-null int64
# profile_image_url       100000 non-null object
# user_statuses_count     100000 non-null int64
# user_friends_count      100000 non-null int64
# user_followers_count    100000 non-null int64
# user_created_at         100000 non-null object
# user_bio                72428 non-null object
# user_location           63977 non-null object
# lang                    100000 non-null object
# code                    100000 non-null object
# ...

# %%
df.head(1)
# Out:
#    id                                                         guid  \
# 0  1   https://twitter.com/eusantinha/statuses/1134507592393338880
#
#                                                           link  \
# 0  https://twitter.com/eusantinha/statuses/1134507592393338880
#
#                pubdate      author  \
# 0  2019-05-31 13:11:02  eusantinha
#
#                                                                                                 title  \
# 0  RT @roxmo: Entrevista com Jair Bolsonaro | The Noite (30/05/19) - YouTube\nhttps://t.co/IB3tf4FjG1
#
#                                                                                description  \
# 0  Entrevista com Jair Bolsonaro | The Noite (30/05/19) - YouTube\nhttps://t.co/IB3tf4FjG1
#
#                 source    user_id  \
# 0  Twitter for Android  264930935
#
#                                                               profile_image_url  \
# ...

# %%
df.tail(1)
# Out:
#            id                                                         guid  \
# 99999  100000  https://twitter.com/malamentre/statuses/1135271360723324928
#
#                                                               link  \
# 99999  https://twitter.com/malamentre/statuses/1135271360723324928
#
#                    pubdate      author  \
# 99999  2019-06-02 15:45:59  malamentre
#
#                                                          title  \
# 99999  o bolsonaro fugindo dos debates https://t.co/NdeQ9YBlop
#
#                                                    description  \
# 99999  o bolsonaro fugindo dos debates https://t.co/NdeQ9YBlop
#
#                    source              user_id  \
# 99999  Twitter Web Client  1134662223970951173
#
#                                                                   profile_image_url  \
# 99999  https://pbs.twimg.com/profile_images/1134674537327599621/--dj1oPb_normal.jpg
#
# ...

# %%
df['pubdate'] = pd.to_datetime(df['pubdate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
# id                      100000 non-null int64
# guid                    100000 non-null object
# link                    100000 non-null object
# pubdate                 100000 non-null datetime64[ns]
# author                  100000 non-null object
# title                   100000 non-null object
# description             100000 non-null object
# source                  100000 non-null object
# user_id                 100000 non-null int64
# profile_image_url       100000 non-null object
# user_statuses_count     100000 non-null int64
# user_friends_count      100000 non-null int64
# user_followers_count    100000 non-null int64
# user_created_at         100000 non-null object
# user_bio                72428 non-null object
# user_location           63977 non-null object
# lang                    100000 non-null object
# code                    100000 non-null object
# ...

# %%
df.set_index('pubdate', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100000 entries, 2019-05-31 13:11:02 to 2019-06-02 15:45:59
# Data columns (total 18 columns):
# id                      100000 non-null int64
# guid                    100000 non-null object
# link                    100000 non-null object
# author                  100000 non-null object
# title                   100000 non-null object
# description             100000 non-null object
# source                  100000 non-null object
# user_id                 100000 non-null int64
# profile_image_url       100000 non-null object
# user_statuses_count     100000 non-null int64
# user_friends_count      100000 non-null int64
# user_followers_count    100000 non-null int64
# user_created_at         100000 non-null object
# user_bio                72428 non-null object
# user_location           63977 non-null object
# lang                    100000 non-null object
# code                    100000 non-null object
# ...

# %%
df.head()
# Out:
#                      id  \
# pubdate
# 2019-05-31 13:11:02  1
# 2019-05-31 13:11:02  2
# 2019-05-31 13:11:01  3
# 2019-05-31 13:11:00  4
# 2019-05-31 13:10:57  5
#
#                                                                                  guid  \
# pubdate
# 2019-05-31 13:11:02  https://twitter.com/eusantinha/statuses/1134507592393338880
# 2019-05-31 13:11:02  https://twitter.com/EmersonCGomes1/statuses/1134507591390941184
# 2019-05-31 13:11:01  https://twitter.com/rcsarabia/statuses/1134507586491998208
# 2019-05-31 13:11:00  https://twitter.com/BethGuimares8/statuses/1134507583782477824
# 2019-05-31 13:10:57  https://twitter.com/Cristinamaciel0/statuses/1134507570071257088
#
#                                                                                  link  \
# pubdate
# 2019-05-31 13:11:02  https://twitter.com/eusantinha/statuses/1134507592393338880
# 2019-05-31 13:11:02  https://twitter.com/EmersonCGomes1/statuses/1134507591390941184
# ...

# %%
no_june = df.loc['2019-05-01':'2019-05-31']
no_june.head()
# Out:
#                      id  \
# pubdate
# 2019-05-31 13:11:02  1
# 2019-05-31 13:11:02  2
# 2019-05-31 13:11:01  3
# 2019-05-31 13:11:00  4
# 2019-05-31 13:10:57  5
#
#                                                                                  guid  \
# pubdate
# 2019-05-31 13:11:02  https://twitter.com/eusantinha/statuses/1134507592393338880
# 2019-05-31 13:11:02  https://twitter.com/EmersonCGomes1/statuses/1134507591390941184
# 2019-05-31 13:11:01  https://twitter.com/rcsarabia/statuses/1134507586491998208
# 2019-05-31 13:11:00  https://twitter.com/BethGuimares8/statuses/1134507583782477824
# 2019-05-31 13:10:57  https://twitter.com/Cristinamaciel0/statuses/1134507570071257088
#
#                                                                                  link  \
# pubdate
# 2019-05-31 13:11:02  https://twitter.com/eusantinha/statuses/1134507592393338880
# 2019-05-31 13:11:02  https://twitter.com/EmersonCGomes1/statuses/1134507591390941184
# ...

# %%
df.shape
# Out:
# (100000, 18)

# %%
no_june.shape
# Out:
# (20993, 18)

# %%
len(df) - len(no_june)
# Out:
# 79007

# %%
writer = pd.ExcelWriter(r'data/02_no_june/40.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
no_april.to_excel(writer)
writer.close()
