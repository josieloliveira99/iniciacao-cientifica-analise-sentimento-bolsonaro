# %%
import pandas as pd
import random
import utils.functions as f
from utils.stop_words_custom import my_stop_words as stop_words
pd.set_option('display.max_colwidth', -1)

# %%
data = "data/00_initial/30.xlsx"

# %%
df = f.get_data(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
# id                      100000 non-null int64
# guid                    100000 non-null object
# link                    100000 non-null object
# pubdate                 100000 non-null object
# author                  100000 non-null object
# title                   100000 non-null object
# description             100000 non-null object
# source                  100000 non-null object
# user_id                 100000 non-null int64
# profile_image_url       100000 non-null object
# user_statuses_count     100000 non-null int64
# user_friends_count      100000 non-null int64
# user_followers_count    100000 non-null int64
# user_created_at         100000 non-null object
# user_bio                74150 non-null object
# user_location           66096 non-null object
# lang                    100000 non-null object
# code                    100000 non-null object
# ...

# %%
df.head(1)
# Out:
#    id                                                       guid  \
# 0  1   https://twitter.com/spotefai/statuses/1123088524562116608
#
#                                                         link  \
# 0  https://twitter.com/spotefai/statuses/1123088524562116608
#
#                pubdate    author  \
# 0  2019-04-30 00:55:44  spotefai
#
#                                                                                                                                             title  \
# 0  RT @felipeneto: Tradução da fala do Bolsonaro:\n\n“Quem quiser fazer turismo sexual aqui, fique à vontade. Pode explorar a mulher brasileira,…
#
#                                                                                                                                                                                                                                                                                      description  \
# ...

# %%
df.tail(1)
# Out:
#            id                                                       guid  \
# 99999  100000  https://twitter.com/marilwma/statuses/1124432218565292032
#
#                                                             link  \
# 99999  https://twitter.com/marilwma/statuses/1124432218565292032
#
#                    pubdate    author  \
# 99999  2019-05-03 17:55:06  marilwma
#
#                                                                                             title  \
# 99999  RT @bolinhaprov: vai toma no cu 107 anos de ufpr e eu entro nela bem na época do bolsonaro
#
#                                                                      description  \
# 99999  vai toma no cu 107 anos de ufpr e eu entro nela bem na época do bolsonaro
#
#                     source              user_id  \
# 99999  Twitter for Android  1072985675748831242
#
#                                                                   profile_image_url  \
# ...

# %%
df['pubdate'] = pd.to_datetime(df['pubdate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
# id                      100000 non-null int64
# guid                    100000 non-null object
# link                    100000 non-null object
# pubdate                 100000 non-null datetime64[ns]
# author                  100000 non-null object
# title                   100000 non-null object
# description             100000 non-null object
# source                  100000 non-null object
# user_id                 100000 non-null int64
# profile_image_url       100000 non-null object
# user_statuses_count     100000 non-null int64
# user_friends_count      100000 non-null int64
# user_followers_count    100000 non-null int64
# user_created_at         100000 non-null object
# user_bio                74150 non-null object
# user_location           66096 non-null object
# lang                    100000 non-null object
# code                    100000 non-null object
# ...

# %%
df.set_index('pubdate', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100000 entries, 2019-04-30 00:55:44 to 2019-05-03 17:55:06
# Data columns (total 18 columns):
# id                      100000 non-null int64
# guid                    100000 non-null object
# link                    100000 non-null object
# author                  100000 non-null object
# title                   100000 non-null object
# description             100000 non-null object
# source                  100000 non-null object
# user_id                 100000 non-null int64
# profile_image_url       100000 non-null object
# user_statuses_count     100000 non-null int64
# user_friends_count      100000 non-null int64
# user_followers_count    100000 non-null int64
# user_created_at         100000 non-null object
# user_bio                74150 non-null object
# user_location           66096 non-null object
# lang                    100000 non-null object
# code                    100000 non-null object
# ...

# %%
df.head()
# Out:
#                      id  \
# pubdate
# 2019-04-30 00:55:44  1
# 2019-04-30 00:55:43  2
# 2019-04-30 00:55:42  3
# 2019-04-30 00:55:38  4
# 2019-04-30 00:55:38  5
#
#                                                                                  guid  \
# pubdate
# 2019-04-30 00:55:44  https://twitter.com/spotefai/statuses/1123088524562116608
# 2019-04-30 00:55:43  https://twitter.com/BetoPereira19/statuses/1123088519822565376
# 2019-04-30 00:55:42  https://twitter.com/JurunaPDT12/statuses/1123088514357301248
# 2019-04-30 00:55:38  https://twitter.com/cid_pistola/statuses/1123088498876141568
# 2019-04-30 00:55:38  https://twitter.com/rutherfordtnbhd/statuses/1123088498532204544
#
#                                                                                  link  \
# pubdate
# 2019-04-30 00:55:44  https://twitter.com/spotefai/statuses/1123088524562116608
# 2019-04-30 00:55:43  https://twitter.com/BetoPereira19/statuses/1123088519822565376
# ...

# %%
no_april = df.loc['2019-05-01':'2019-05-31']
no_april.head()
# Out:
#                         id  \
# pubdate
# 2019-05-01 02:25:51  24000
# 2019-05-01 02:25:47  24001
# 2019-05-01 02:25:45  24002
# 2019-05-01 02:25:45  24003
# 2019-05-01 02:25:44  24004
#
#                                                                               guid  \
# pubdate
# 2019-05-01 02:25:51  https://twitter.com/fabianafn/statuses/1123473589460721666
# 2019-05-01 02:25:47  https://twitter.com/SergioT1910/statuses/1123473572364791809
# 2019-05-01 02:25:45  https://twitter.com/nuno_marqs/statuses/1123473565133811713
# 2019-05-01 02:25:45  https://twitter.com/Cleo23357718/statuses/1123473564227776513
# 2019-05-01 02:25:44  https://twitter.com/ritac_aa/statuses/1123473558188044294
#
#                                                                               link  \
# pubdate
# 2019-05-01 02:25:51  https://twitter.com/fabianafn/statuses/1123473589460721666
# 2019-05-01 02:25:47  https://twitter.com/SergioT1910/statuses/1123473572364791809
# ...

# %%
df.shape
# Out:
# (100000, 18)

# %%
no_april.shape
# Out:
# (76001, 18)

# %%
len(df) - len(no_april)
# Out:
# 23999

# %%
writer = pd.ExcelWriter(r'data/01_no_april/30.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
no_april.to_excel(writer)
writer.close()
