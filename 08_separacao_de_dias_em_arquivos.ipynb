# %%
import pandas as pd
import random
import re
import utils.functions as f
from utils.stop_words_custom import my_stop_words as stop_words
pd.set_option('display.max_colwidth', -1)

# %%
df = f.get_data('data/07_repeated_descriptions_deleted/without_repeated_descriptions.xlsx')

# %%
df.set_index('pubdate', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 226773 entries, 2019-05-01 02:06:12 to 2019-05-31 23:59:40
# Data columns (total 18 columns):
# id                      226773 non-null int64
# guid                    226773 non-null object
# link                    226773 non-null object
# author                  226773 non-null object
# title                   226772 non-null object
# description             226772 non-null object
# source                  226773 non-null object
# user_id                 226773 non-null int64
# profile_image_url       226773 non-null object
# user_statuses_count     226773 non-null int64
# user_friends_count      226773 non-null int64
# user_followers_count    226773 non-null int64
# user_created_at         226773 non-null object
# user_bio                171591 non-null object
# user_location           151316 non-null object
# lang                    226773 non-null object
# code                    226773 non-null object
# ...

# %%
df.head()
# Out:
#                         id  \
# pubdate
# 2019-05-01 02:06:12  24834
# 2019-05-01 02:06:18  24832
# 2019-05-01 02:06:18  24831
# 2019-05-01 02:06:20  24829
# 2019-05-01 02:06:22  24827
#
#                                                                                  guid  \
# pubdate
# 2019-05-01 02:06:12  https://twitter.com/wesleyespindula/statuses/1123468644929953797
# 2019-05-01 02:06:18  https://twitter.com/diogoandrew85/statuses/1123468668128698368
# 2019-05-01 02:06:18  https://twitter.com/andrearoeirap/statuses/1123468668740997120
# 2019-05-01 02:06:20  https://twitter.com/_criscorrea/statuses/1123468679180685312
# 2019-05-01 02:06:22  https://twitter.com/AuricelCarvalho/statuses/1123468687216922624
#
#                                                                                  link  \
# pubdate
# 2019-05-01 02:06:12  https://twitter.com/wesleyespindula/statuses/1123468644929953797
# 2019-05-01 02:06:18  https://twitter.com/diogoandrew85/statuses/1123468668128698368
# ...

# %%
dict_bolsonaro = {}
for i in range(1,32):  
    if(i<10):      
        start = '2019-05-0{}'.format(str(i))
        end   = '2019-05-0{}'.format(str(i))
        name = '2019-05-0{}'.format(str(i))
        dict_bolsonaro[name] = df[start:end]
    else:
        start = '2019-05-{}'.format(str(i))
        end   = '2019-05-{}'.format(str(i))
        name = '2019-05-{}'.format(str(i))
        dict_bolsonaro[name] = df[start:end]
        
    writer = pd.ExcelWriter(r'data/08_separated_day_files/{}.xlsx'.format(name), engine='xlsxwriter',options={'strings_to_urls': False})
    dict_bolsonaro[name].to_excel(writer)
    writer.close()
