# %%
import pandas as pd
import random
import re
import utils.functions as f
from utils.stop_words_custom import my_stop_words as stop_words
pd.set_option('display.max_colwidth', -1)

# %%
df = f.get_data("data/03_just_may/may.xlsx")

# %%
df['pubdate'] = pd.to_datetime(df['pubdate'])

# %%
df.sort_values(by=['pubdate'],inplace=True)

# %%
df.tail()
# Out:
#                   pubdate     id  \
# 20823 2019-05-31 23:59:49  21287
# 20822 2019-05-31 23:59:50  21286
# 20821 2019-05-31 23:59:57  21285
# 20819 2019-05-31 23:59:59  21283
# 20820 2019-05-31 23:59:59  21284
#
#                                                                guid  \
# 20823  https://twitter.com/pietrovte/statuses/1134670862865620993
# 20822  https://twitter.com/Daan77/statuses/1134670867663872006
# 20821  https://twitter.com/Blazar147/statuses/1134670898341044225
# 20819  https://twitter.com/marciav2015/statuses/1134670906545115136
# 20820  https://twitter.com/Dihwitter/statuses/1134670903953018881
#
#                                                                link  \
# 20823  https://twitter.com/pietrovte/statuses/1134670862865620993
# 20822  https://twitter.com/Daan77/statuses/1134670867663872006
# 20821  https://twitter.com/Blazar147/statuses/1134670898341044225
# 20819  https://twitter.com/marciav2015/statuses/1134670906545115136
# ...

# %%
writer = pd.ExcelWriter(r'data/05_ordered_may/may_ordered.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer)
writer.close()
