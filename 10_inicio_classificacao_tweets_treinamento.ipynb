# %%
import pandas as pd
import random
import re
import utils.functions as f
from utils.stop_words_custom import my_stop_words as stop_words
pd.set_option('display.max_colwidth', -1)

# %%
df = f.get_data('data/09_columns_deleteds/columns_deleteds.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226772 entries, 834 to 20829
# Data columns (total 6 columns):
# pubdate            226772 non-null datetime64[ns]
# id                 226772 non-null int64
# author             226772 non-null object
# description        226772 non-null object
# user_created_at    226772 non-null object
# user_bio           171591 non-null object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 12.1+ MB

# %%
df.dropna(subset=['description'],inplace=True)

# %%
classified  = []
description = []
classes     = []
positive    = []
negative    = []
neutral     = []
i           = 0

users_bio_negative = ["Manifestem-se! Só um velho engenheiro econômico aposentado, um vagabundo a mais, segundo um conhecido sociopata canalha! #EsquerdistasSeguemEsquerdistas","Engenheiro Civil. Petista,Lulista,Pacifista,Anti-Preconceitos,Corintiano e sobretudo BRASILEIRO.#LULALIVRE","Precisamos vencer a fome, a miséria e a exclusão social. Nossa guerra não é para matar ninguém - é para salvar vidas.\n\nLuiz Inácio Lula da Silva","CASADO, PAI DE 3, AVÔ DE 2 ATÉ AGORA, CATÓLICO, FLAMENGUISTA, ENGo.TELECOM, BRIZOLISTA RADICALMENTE ANTI-DIREITA!   #EsquerdistasSeguemEsquerdistas"                     
    ]

for index,data in df.iterrows():
    row = data["description"]
    if isinstance(data["user_bio"],str):
        if("#Dia15GreveGeralNaEducação" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif(row in users_bio_negative):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#ArmasMatam" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#NaoVaiTerCorteVaiTerLuta" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#EleNao" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#ForaBolsonaro" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#CadêOQueiroz" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#SomosTodosLeticia" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#CadeOQueiroz" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#BolsonaroEnvergonhaOBrasil" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#UniversidadesContraBolsonaro" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#CancelBolsonaro" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#PersonulidadeDoAno" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#LulaLivre" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#LulaInspira" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#takeitdownMarriott" in row):
            negative.append(row)
            description.append(row)
            classes.append("negative")
        elif("#Bolsonaro2022" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#BrasilÉBolsonaro" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#PTNuncaMais" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#elesim" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#DireitaUnida" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#EstouComBolsonaro" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#BolsonaroOrgulhodoBrasil" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#BolsoSilvioVemAi" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#BolsoNoSBT" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#BoicoteBurgerKing" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#CentraoBlocoDeLadrao" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
        elif("#B2022" in row):
            positive.append(row)
            description.append(row)
            classes.append("positive")
    i = i+ 1

# %%
classified = pd.DataFrame(classified)
classified["description"] = description
classified["class"] = classes

# %%
classified.head()
# Out:
#                                                                                                                                                                                                                                                                                 description  \
# 0  É chegada a hora do Congresso reagir com um pedido de impeachment de Bolsonaro e sua equipe. Estão colocando o país e a população em risco graças a incompetência administrativa para resolver os problemas internos porque no exterior nossa diplomacia não existe #ForaBolsonaroEBando
# 1  Como sempre se afirmou e agora se confirma, Lula é preso político. #LulaLivreQuartaSDV No que depender de nós, Lula não terá chance de liberdade, diz Bolsonaro - 30/04/2019 - UOL Notícias https://t.co/Huj49HF2d3
# 2  #JairBolsonaro empregava cinco funcionárias que nunca foram ao Congresso #BolsonaroEnvergonhaOBrasil https://t.co/bkJDe2by2c via @exame
# ...

# %%
classified["class"].value_counts()
# Out:
# negative    1324
# positive    795
# Name: class, dtype: int64

# %%
for tweet in positive[0:50]:
    print(tweet)
    print("-------------")
# Out:
# @DeputadoFederal Meu Deus, eu não te bloqueei ainda, me perdoe nobre excremento, eu já devia ter feito isto antes, foi mal mesmo.
# #Bolsonaro2022
# #Bolsonaro
# -------------
# @RodrigoMaia Eita inveja!!
# Eita vontade de set Presidente da República!!
# Eu votei em Bolsonaro 🔰
# #Bolsonaro2022
# -------------
# Não vai adiantar. Quando elegemos o Presidente Bolsonaro, sabíamos que ele enfrentaria esses políticos, que não pensam na população, mas sim voltar ao poder e transformar o Brasil em uma ditadura socialista.
# #Bolsonaro2022 https://t.co/MfCyeNosTa
# -------------
# @Estadao @EstadaoPolitica Já estão com medo?
# Mas o Bolsonaro não é um presidente ruim?
# #Bolsonaro2022
# -------------
# @TomCoelho10 @folha Pode ter certeza que Bolsonaro será reeleito,votei nele e votarei de novo... E os 57 milhões de votos ke tevr em 2018 irao ter acrescimos consideráveis,  boicotar o pais e burrice, e se boicotarem ai ke vao perder...#Bolsonaro2022
# -------------
# ...

# %%
writer = pd.ExcelWriter(r'data/10_classify_tweets/classify_tweets.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
classified.to_excel(writer)
writer.close()
